# %% [markdown]
# References **[Pandas Home Page](https://www.kaggle.com/learn/pandas)**
#
# ---

# %% [markdown]
# Run the following cell to load the bangalore restaurants data

# %%
import pandas as pd
import numpy as np

restaurants = pd.read_csv('data/zomato.csv')

# %% [markdown]
# Look at an overview of your data by running the following line.

# %%
restaurants.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %% [markdown]
# # Exercises

# %% [markdown]
# ## 1.
#
# Select the `online_order` column from `restaurants` and assign the result to the variable `ol_order`.

# %%
# Your code here
ol_order = restaurants["online_order"]

# Check your answer
ol_order
# Out:
# 0        Yes
# 1        Yes
# 2        Yes
# 3         No
# 4         No
#         ...
# 51712     No
# 51713     No
# 51714     No
# 51715     No
# 51716     No
# Name: online_order, Length: 51717, dtype: object

# %% [markdown]
# What type of object is `ol_order`? If you're not sure, you can check by calling Python's `type` function: `type(ol_order)`.

# %%
type(ol_order)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## 2.
#
# Select the first value from the `dish_liked` column of `restaurants`, assigning it to variable `first_rest_reviews`.
#
# <br><br> Output should be:<br>`'Pasta, Lunch Buffet, Masala Papad, Paneer Lajawab, Tomato Shorba, Dum Biryani, Sweet Corn Soup'`

# %%
first_rest_reviews = restaurants.dish_liked[0]

# Check your answer

first_rest_reviews
# Out:
# 'Pasta, Lunch Buffet, Masala Papad, Paneer Lajawab, Tomato Shorba, Dum Biryani, Sweet Corn Soup'

# %% [markdown]
# ## 3.
#
# Select the first row of data (the first record) from `restaurants`, assigning it to the variable `first_row`.

# %%
first_row = restaurants.iloc[0, :]


first_row
# Out:
# url                            https://www.zomato.com/bangalore/jalsa-banasha...
# address                        942, 21st Main Road, 2nd Stage, Banashankari, ...
# name                                                                       Jalsa
# online_order                                                                 Yes
# book_table                                                                   Yes
# rate                                                                       4.1/5
# votes                                                                        775
# phone                                             080 42297555\r\n+91 9743772233
# location                                                            Banashankari
# rest_type                                                          Casual Dining
# dish_liked                     Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# cuisines                                          North Indian, Mughlai, Chinese
# ...

# %% [markdown]
# ## 4.
#
# Select the first 10 values from the `approx_cost(for two people)` column in `restaurants`, assigning the result to variable `cost_selection`.
#
# Hint: format your output as a pandas Series.

# %%
#cost_selection = restaurants["approx_cost(for two people)"].iloc[:10]
cost_selection = restaurants.loc[:9, "approx_cost(for two people)"]

# Check your answer

cost_selection
# Out:
# 0    800
# 1    800
# 2    800
# 3    300
# 4    600
# 5    600
# 6    800
# 7    600
# 8    700
# 9    550
# Name: approx_cost(for two people), dtype: object

# %% [markdown]
# ## 5.
#
# Select the records with index labels `2`, `4`, `6`, `8`, and `10`, assigning the result to the variable `sub_set`.
#
# Should look like this:
# <div>
# <img src="images/subset.png" width="750"/>
# </div>

# %%
sub_set = restaurants.loc[[2, 4, 6, 8, 10]]

# Check your answer
sub_set
# Out:
#                                                   url  \
# 2   https://www.zomato.com/SanchurroBangalore?cont...
# 4   https://www.zomato.com/bangalore/grand-village...
# 6   https://www.zomato.com/bangalore/rosewood-inte...
# 8   https://www.zomato.com/bangalore/penthouse-caf...
# 10  https://www.zomato.com/bangalore/caf%C3%A9-dow...
#
#                                               address  \
# 2   1112, Next to KIMS Medical College, 17th Cross...
# 4   10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# 6   19/1, New Timberyard Layout, Beside Satellite ...
# 8   1, 30th Main Road, 3rd Stage, Banashankari, Ba...
# 10  12,29 Near PES University Back Gate, D'Souza N...
#
#                                                  name online_order book_table  \
# 2                                     San Churro Cafe          Yes         No
# 4                                       Grand Village           No         No
# ...

# %% [markdown]
# Use the len() function to determine how many reviews our csv contains - (51717)

# %%
len(restaurants)
# Out:
# 51717

# %% [markdown]
# If we want to sample our data we may decide to take every nth data point.<br><br> Select every 1000th entry in our dataframe.<br> Do this by using an array of the values - `[0,1000,2000,3000,......49000,50000,51000]` <br>(Hint - You should be able to do this using np.arange - this will require importing the numpy library!)

# %%
fixed_selection = restaurants.iloc[::1000, :]
# fixed_selection = np.arange(0,len(restaurants),1000)
fixed_selection
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1000   https://www.zomato.com/bangalore/andhra-ruchul...
# 2000   https://www.zomato.com/bangalore/guru-garden-b...
# 3000   https://www.zomato.com/bangalore/kudla-hotel-r...
# 4000   https://www.zomato.com/bangalore/uptown-slider...
# 5000   https://www.zomato.com/bangalore/red-onion-sha...
# 6000   https://www.zomato.com/bangalore/dunkin-donuts...
# 7000   https://www.zomato.com/bangalore/curries-pickl...
# 8000   https://www.zomato.com/bangalore/slounge-lemon...
# 9000   https://www.zomato.com/bangalore/punjabi-corne...
# 10000  https://www.zomato.com/bangalore/north-indian-...
# 11000  https://www.zomato.com/bangalore/crafted-plate...
# 12000  https://www.zomato.com/bangalore/backyard-rich...
# 13000  https://www.zomato.com/bangalore/chaitanya-veg...
# 14000  https://www.zomato.com/bangalore/cake-menu-1-e...
# ...

# %% [markdown]
# It would be more correct to take an absolutely random selection - as there may be an ordering in the data we are not aware of.<br><br> Select every 50 completely random entries<br> Do this by using an array of random values between 0 and 51717 <br>(Hint - You should be able to do this using the numpy library you already imported!)

# %%
random_selection = np.random.randint(51517, size=50)

r = restaurants.loc[random_selection]
r
# Out:
#                                                      url  \
# 5209   https://www.zomato.com/bangalore/the-waffle-pr...
# 44038  https://www.zomato.com/bangalore/zam-zam-kabab...
# 18247  https://www.zomato.com/bangalore/huga-icecream...
# 48136  https://www.zomato.com/bangalore/taste-of-kera...
# 25664  https://www.zomato.com/bangalore/manjit-da-dha...
# 36748  https://www.zomato.com/bangalore/pot-o-noodles...
# 50025  https://www.zomato.com/bangalore/inhouse-burge...
# 50249  https://www.zomato.com/bangalore/andhra-kafe-w...
# 37658  https://www.zomato.com/bangalore/skywalk-resto...
# 38666  https://www.zomato.com/bangalore/bangalore-pub...
# 25264  https://www.zomato.com/bangalore/srinidhi-veg-...
# 22829  https://www.zomato.com/bangalore/fritz-haber-b...
# 33343  https://www.zomato.com/bangalore/stoked-korama...
# 27257  https://www.zomato.com/bangalore/chillout-btm-...
# 42060  https://www.zomato.com/bangalore/rekha-restaur...
# ...

# %% [markdown]
# ## 6.
#
# Create a variable `dataframe` containing the `address`, `name`, `book_table`,`rate`,and `listed_in(city)` columns of the records with the index labels `0`, `5`, `50`,`500`, and `5000`. In other words, generate the following DataFrame:
#
# ![](images/subset2.png)

# %%
dataframe = restaurants.loc[[0, 5, 50, 500, 5000, 50000], ["address", "name", "book_table", "rate", "listed_in(city)"]]

# Check your answer
dataframe
# Out:
#                                                  address             name  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...            Jalsa
# 5      37, 5-1, 4th Floor, Bosco Court, Gandhi Bazaar...  Timepass Dinner
# 50     276, Ground Floor, 100 Feet Outer Ring Road, B...            Petoo
# 500    374/B, 2nd Phase, BSK 3rd Stage, Srinivasa Nag...     Kanti Sweets
# 5000   Money Chambers Double Road, Shanti Nagar, Bang...        Red Onion
# 50000  RMZ Eco Space, Varthur Hobli, Bellandur, Banga...     Costa Coffee
#
#       book_table    rate listed_in(city)
# 0            Yes   4.1/5    Banashankari
# 5             No   3.8/5    Banashankari
# 50            No   3.7/5    Banashankari
# 500           No   4.0/5    Banashankari
# 5000         Yes  4.2 /5    Brigade Road
# 50000         No  3.0 /5   Sarjapur Road

# %% [markdown]
# ## 7.
#
# Create a variable `df` containing the `address`, `name`, `book_table`,`rate`, and `listed_in(city)` columns of the first 100 records.
#
# Hint: you may use `loc` or `iloc`. When working on the answer this question and the several of the ones that follow, keep the following "gotcha" described in the tutorial:
#
# > `iloc` uses the Python stdlib indexing scheme, where the first element of the range is included and the last one excluded.
# `loc`, meanwhile, indexes inclusively.
#
# > This is particularly confusing when the DataFrame index is a simple numerical list, e.g. `0,...,1000`. In this case `df.iloc[0:1000]` will return 1000 entries, while `df.loc[0:1000]` return 1001 of them! To get 1000 elements using `loc`, you will need to go one lower and ask for `df.iloc[0:999]`.

# %%
df = restaurants.loc[:100, ["address", "name", "book_table", "rate", "listed_in(city)"]]
# Check your answer
df
# Out:
#                                                address                   name  \
# 0    942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1    2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2    1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3    1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4    10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
# ..                                                 ...                    ...
# 96   50 Feet Road, Hanumanthanagar, Banashankari, B...                 Kaggis
# 97   34, 22nd Main, 22nd Cross, Opposite BDA, 2nd S...   Ayda Persian Kitchen
# 98   24/1, 23rd Cross, 6th Main Road, Opposite Kave...           Chatar Patar
# 99   96, Opposite Jain Collage, Basavanagudi, Banga...             Polar Bear
# 100  2465, 3rd Floor, Opposite BDA Complex, 24th Cr...      Kidambi's Kitchen
#
# ...

# %% [markdown]
# ## 8.
#
# Create a DataFrame `restaurants` in `Bellandur`. Hint: `restaurants.location` equals what?

# %%
bellandur_restaurants = restaurants.loc[restaurants.location=="Bellandur"]

# bellandur_restaurants = restaurants[restaurants.location=="Bellandur"]

# Check your answer
bellandur_restaurants
# Out:
#                                                      url  \
# 3746   https://www.zomato.com/bangalore/kava-fairfiel...
# 3748   https://www.zomato.com/bangalore/momo-cafe-cou...
# 3749   https://www.zomato.com/bangalore/ruh-bellandur...
# 3750   https://www.zomato.com/bangalore/tipsy-bull-th...
# 3751   https://www.zomato.com/bangalore/nook-aloft-be...
# ...                                                  ...
# 50096  https://www.zomato.com/bangalore/atithi-family...
# 50134  https://www.zomato.com/bangalore/re-fuel-aloft...
# 51033  https://www.zomato.com/bangalore/re-fuel-aloft...
# 51628  https://www.zomato.com/bangalore/nook-aloft-be...
# 51633  https://www.zomato.com/bangalore/re-fuel-aloft...
#
#                                                  address  \
# 3746   Fairfield by Marriott, Marathahalli - Sarjapur...
# 3748   Courtyard by Marriott, Marathahalli-Sarjapur O...
# 3749   4th Floor, Ganapa Tower, Sarjapur Outer Ring R...
# ...

# %% [markdown]
# ## 9.
#
# Create a DataFrame `Electronic_City_takeaways` containing all restaurants in Electronic City that take online orders

# %%
Electronic_City_takeaways = restaurants.loc[restaurants.online_order=="Yes"].loc[restaurants.location=="Electronic City"]

# Electronic_City_takeaways = restaurants.loc[(restaurants.location=="Electronic City") & (restaurants.online_order=="Yes")]

# Check your answer
Electronic_City_takeaways
# Out:
#                                                      url  \
# 1684   https://www.zomato.com/bangalore/ministry-of-b...
# 2395   https://www.zomato.com/bangalore/zatar-house-1...
# 13370  https://www.zomato.com/bangalore/onesta-electr...
# 13371  https://www.zomato.com/bangalore/time-travelle...
# 13376  https://www.zomato.com/bangalore/aagaman-veg-e...
# ...                                                  ...
# 17397  https://www.zomato.com/bangalore/nmr-multicuis...
# 17409  https://www.zomato.com/bangalore/godavari-deli...
# 17475  https://www.zomato.com/bangalore/halli-mane-ba...
# 17479  https://www.zomato.com/bangalore/biryani-darba...
# 23602  https://www.zomato.com/bangalore/zatar-house-1...
#
#                                                  address  \
# 1684   No 121/1, Abhinandana Complex, Manipal Country...
# 2395   V-8, 3rd Cross, Keonics Road, Electronic City,...
# 13370  Sy No: 54/2 ( Old Sy no 54 ), Above BATA showr...
# ...

# %% [markdown]
# ## 10.
# You and your friend want to go to a Restaurant.<br>
# You would like Pasta and they would like Saag. Get a list of the restaurants that would suit your preferences.<br>
# Once you have a list of suitable places select the reataurants that will both take a booking and an online order.

# %%
fav = restaurants.menu_item.map(lambda menu: ("Pasta" in menu) & ("Saag" in menu))
result = restaurants[fav].loc[restaurants.book_table == "Yes"].loc[restaurants.online_order=="Yes"]

result
# Out:
#                                                      url  \
# 5564   https://www.zomato.com/bangalore/raaga-indiran...
# 10876  https://www.zomato.com/bangalore/brooks-and-bo...
# 15121  https://www.zomato.com/bangalore/raaga-indiran...
# 17542  https://www.zomato.com/bangalore/srinathjis-in...
# 17543  https://www.zomato.com/bangalore/raaga-indiran...
# 19884  https://www.zomato.com/bangalore/brooks-and-bo...
# 27047  https://www.zomato.com/bangalore/brooks-and-bo...
# 28385  https://www.zomato.com/bangalore/the-bier-libr...
# 28397  https://www.zomato.com/bangalore/brooks-and-bo...
# 29959  https://www.zomato.com/bangalore/brooks-and-bo...
# 32624  https://www.zomato.com/bangalore/brooks-and-bo...
# 33634  https://www.zomato.com/bangalore/the-bier-libr...
# 35270  https://www.zomato.com/bangalore/brooks-and-bo...
# 37550  https://www.zomato.com/bangalore/brooks-and-bo...
# 38450  https://www.zomato.com/bangalore/the-bangalore...
# ...

# %%
restaurants.columns
restaurants['listed_in(city)'].value_counts()
# Out:
# BTM                      3279
# Koramangala 7th Block    2938
# Koramangala 5th Block    2836
# Koramangala 4th Block    2779
# Koramangala 6th Block    2623
# Jayanagar                2371
# JP Nagar                 2096
# Indiranagar              1860
# Church Street            1827
# MG Road                  1811
# Brigade Road             1769
# Lavelle Road             1744
# HSR                      1741
# Marathahalli             1659
# Residency Road           1620
# Whitefield               1620
# Bannerghatta Road        1617
# Brookefield              1518
# Old Airport Road         1425
# Kammanahalli             1329
# Kalyan Nagar             1309
# Basavanagudi             1266
# Sarjapur Road            1261
# Electronic City          1229
# Bellandur                1227
# Frazer Town              1185
# Malleshwaram             1096
# Rajajinagar              1079
# Banashankari              863
# New BEL Road              740
# Name: listed_in(city), dtype: int64
